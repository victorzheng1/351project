# %% [markdown]
# # Kidney

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os

# %%
import torch

# %%
BATCH_SIZE = 50
froot = "D:\\CISC351\\Group_Project_Data\\CCRCC_JPEG"

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset =

# %%
print(os.listdir("D:\\CISC351\\Group_Project_Data\\CCRCC_JPEG"))
# Out:
# ['C3L-00004-21.dzi', 'C3L-00004-21_files', 'C3L-00004-26.dzi', 'C3L-00004-26_files', 'C3L-00010-21.dzi', 'C3L-00010-21_files', 'C3L-00010-26.dzi', 'C3L-00010-26_files', 'C3L-00011-21.dzi', 'C3L-00011-21_files', 'C3L-00011-26.dzi', 'C3L-00011-26_files', 'C3L-00026-21.dzi', 'C3L-00026-21_files', 'C3L-00026-26.dzi', 'C3L-00026-26_files', 'C3L-00079-21.dzi', 'C3L-00079-21_files', 'C3L-00079-26.dzi', 'C3L-00079-26_files', 'C3L-00088-21.dzi', 'C3L-00088-21_files', 'C3L-00088-22.dzi', 'C3L-00088-22_files', 'C3L-00088-26.dzi', 'C3L-00088-26_files', 'C3L-00096-21.dzi', 'C3L-00096-21_files', 'C3L-00096-26.dzi', 'C3L-00096-26_files', 'C3L-00097-21.dzi', 'C3L-00097-21_files', 'C3L-00097-26.dzi', 'C3L-00097-26_files', 'C3L-00103-21.dzi', 'C3L-00103-21_files', 'C3L-00103-22.dzi', 'C3L-00103-22_files', 'C3L-00103-23.dzi', 'C3L-00103-23_files', 'C3L-00103-26.dzi', 'C3L-00103-26_files', 'C3L-00165-21.dzi', 'C3L-00165-21_files', 'C3L-00165-22.dzi', 'C3L-00165-22_files', 'C3L-00165-23.dzi', 'C3L-00165-
# ...
